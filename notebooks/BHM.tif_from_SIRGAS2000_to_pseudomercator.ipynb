# %%
# Reproject BHM.tif from EPSG:31983 to EPSG:3857 

from osgeo import gdal

ds_repro = gdal.Translate('/Users/konstantinamitsi/Documents/S2DS/DFCCU/data_source_1_maxar/maxar_sample_42tiles/BHM-2222-234_reprojected.tif','/Users/konstantinamitsi/Documents/S2DS/DFCCU/data_source_1_maxar/maxar_sample_42tiles/BHM-2222-234.tif', options='-a_srs EPSG:3857')

# %%
# get the info of the input and output tif files to confirm the reprojection

print(gdal.Info("/Users/konstantinamitsi/Documents/S2DS/DFCCU/data_source_1_maxar/maxar_sample_42tiles/BHM-2222-234.tif"))

print(gdal.Info("/Users/konstantinamitsi/Documents/S2DS/DFCCU/data_source_1_maxar/maxar_sample_42tiles/BHM-2222-234_reprojected.tif"))
# Out:
# Driver: GTiff/GeoTIFF
# Files: /Users/konstantinamitsi/Documents/S2DS/DFCCU/data_source_1_maxar/maxar_sample_42tiles/BHM-2222-234.tif
# Size is 516, 182
# Coordinate System is:
# PROJCRS["SIRGAS 2000 / UTM zone 23S",
#     BASEGEOGCRS["SIRGAS 2000",
#         DATUM["Sistema de Referencia Geocentrico para las AmericaS 2000",
#             ELLIPSOID["GRS 1980",6378137,298.257222101,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4674]],
#     CONVERSION["UTM zone 23S",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-45,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
# ...
